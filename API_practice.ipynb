# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import random
import timeit

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Create a practice set of random latitude and longitude combinations.
x = [25.12903645, 25.92017388, 26.62509167, -59.98969384, 37.30571269]
y = [-67.59741259, 11.09532135, 74.84233102, -76.89176677, -61.13376282]
coordinates = zip(x, y)

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(coordinate[0], coordinate[1])
# Out:
# 25.12903645 -67.59741259
# 25.92017388 11.09532135
# 26.62509167 74.84233102
# -59.98969384 -76.89176677
# 37.30571269 -61.13376282

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Use the tuple() function to display the latitude and longitude combinations.
for coordinate in coordinates:
    print(citipy.nearest_city(coordinate[0], coordinate[1]).city_name,
          citipy.nearest_city(coordinate[0], coordinate[1]).country_code)
# Out:
# egvekinot ru
# avera pf
# mataura pf
# mount gambier au
# saint-philippe re
# castro cl
# valdivia cl
# new norfolk au
# doctor pedro p. pena py
# enshi cn
# jamestown sh
# taolanaro mg
# vaini to
# kushmurun kz
# santarem br
# punta arenas cl
# kaitangata nz
# tilichiki ru
# ushuaia ar
# umm kaddadah sd
# busselton au
# mys shmidta ru
# albany au
# naron es
# artyom az
# attawapiskat ca
# naryan-mar ru
# jizan sa
# horki by
# castro cl
# kuito ao
# gull lake ca
# atikokan ca
# hithadhoo mv
# rikitea pf
# aswan eg
# yulara au
# alpena us
# nizhneyansk ru
# ucluelet ca
# hutchinson us
# mys shmidta ru
# cherskiy ru
# thompson ca
# phalodi in
# kruisfontein za
# bethausen ro
# petropavlovsk-kamchatskiy ru
# hobart au
# saint-philippe re
# praia cv
# chokurdakh ru
# tual id
# mozarlandia br
# kudahuvadhoo mv
# mar del plata ar
# butaritari ki
# kapaa us
# punta arenas cl
# tasiilaq gl
# natal br
# carnarvon au
# chuy uy
# klaksvik fo
# mataura pf
# karaman tr
# olafsvik is
# saskylakh ru
# vaitupu wf
# turochak ru
# freeport us
# mataura pf
# dingle ie
# punta arenas cl
# rikitea pf
# kodiak us
# northport us
# lompoc us
# albany au
# katobu id
# pozzallo it
# mataura pf
# amderma ru
# erzin ru
# punta arenas cl
# mys shmidta ru
# quang ngai vn
# zabaykalsk ru
# albany au
# grand river south east mu
# havre us
# maldonado uy
# bluff nz
# pemangkat id
# ushuaia ar
# kajaani fi
# khatanga ru
# lazaro cardenas mx
# buarcos pt
# donskoye ru
# boundiali ci
# ancud cl
# hami cn
# helena us
# albany au
# hermanus za
# pavlodar kz
# punta arenas cl
# bilibino ru
# mahebourg mu
# tiksi ru
# kuche cn
# hilo us
# belushya guba ru
# la ronge ca
# illoqqortoormiut gl
# taolanaro mg
# mitsamiouli km
# new norfolk au
# barrow us
# punta arenas cl
# punta arenas cl
# qaanaaq gl
# mataura pf
# tuktoyaktuk ca
# castro cl
# yefira gr
# otane nz
# namibe ao
# dingle ie
# alyangula au
# sorong id
# burns lake ca
# puqi cn
# bredasdorp za
# quatre cocos mu
# souillac mu
# tura ru
# road town vg
# praia da vitoria pt
# rikitea pf
# marienburg sr
# hilo us
# vaini to
# nanortalik gl
# tsihombe mg
# hilo us
# ambovombe mg
# grindavik is
# mahebourg mu
# bethel us
# vila franca do campo pt
# illoqqortoormiut gl
# carutapera br
# punta arenas cl
# ahipara nz
# husavik is
# chara ru
# rolim de moura br
# pithoro pk
# ushuaia ar
# komsomolskiy ru
# new norfolk au
# east london za
# avarua ck
# mataura pf
# berlevag no
# semey kz
# hithadhoo mv
# taolanaro mg
# esperance au
# hofn is
# salinas ec
# rikitea pf
# rikitea pf
# alekseyevka kz
# upernavik gl
# jinchang cn
# mar del plata ar
# cody us
# acapulco mx
# san nicolas ar
# cobija bo
# belushya guba ru
# beringovskiy ru
# jamestown sh
# sompeta in
# avarua ck
# port alfred za
# shache cn
# faanui pf
# kapaa us
# rapar in
# saint-ambroise ca
# cherskiy ru
# lebu cl
# punta arenas cl
# ushuaia ar
# cape town za
# marawi sd
# bengkulu id
# kalmunai lk
# nanortalik gl
# cape town za
# catamarca ar
# illoqqortoormiut gl
# tura ru
# punta arenas cl
# new norfolk au
# qaqortoq gl
# tasiilaq gl
# jamestown sh
# port alfred za
# boa vista br
# taolanaro mg
# avarua ck
# salinopolis br
# mason city us
# kaitangata nz
# tuktoyaktuk ca
# atuona pf
# kahului us
# zhigansk ru
# puerto ayora ec
# rikitea pf
# saint-philippe re
# ushuaia ar
# qaanaaq gl
# torbay ca
# barawe so
# punta arenas cl
# karratha au
# upernavik gl
# atuona pf
# mehamn no
# fortuna us
# artyk ru
# vaini to
# airai pw
# guerrero negro mx
# norman wells ca
# comodoro rivadavia ar
# tuktoyaktuk ca
# rikitea pf
# christchurch nz
# hobart au
# albany au
# muros es
# port hardy ca
# bluff nz
# bathsheba bb
# pisco pe
# hilo us
# mataura pf
# new norfolk au
# sedelnikovo ru
# yellowknife ca
# mehamn no
# isla mujeres mx
# ushuaia ar
# tasiilaq gl
# liepaja lv
# umzimvubu za
# rikitea pf
# vaini to
# westport ie
# ponta do sol cv
# barrow us
# carnarvon au
# mar del plata ar
# vagur fo
# nyurba ru
# codrington ag
# belushya guba ru
# hilo us
# qaanaaq gl
# rikitea pf
# ushuaia ar
# codrington ag
# hilo us
# asau tv
# yellowknife ca
# arlit ne
# lorengau pg
# new norfolk au
# yellowknife ca
# bredasdorp za
# sofiysk ru
# vaini to
# nacala mz
# malinyi tz
# tasiilaq gl
# rikitea pf
# kavieng pg
# lebu cl
# albany au
# jamestown sh
# yerbogachen ru
# saint-augustin ca
# punta arenas cl
# nantucket us
# fomboni km
# rawson ar
# hobart au
# uchkent ru
# ushuaia ar
# albany au
# ambilobe mg
# tasiilaq gl
# victoria sc
# georgetown sh
# elk city us
# baherden tm
# mataura pf
# taolanaro mg
# mocuba mz
# anamur tr
# albany au
# tabiauea ki
# ushuaia ar
# amga ru
# busselton au
# atasu kz
# souillac mu
# avarua ck
# karratha au
# vaitape pf
# butaritari ki
# arraial do cabo br
# hilo us
# sioux lookout ca
# saint george bm
# punta arenas cl
# leh in
# tarudant ma
# tasiilaq gl
# faanui pf
# busselton au
# bluff nz
# ushuaia ar
# clyde river ca
# provideniya ru
# taolanaro mg
# tsihombe mg
# tasiilaq gl
# matadi cd
# oranjemund na
# pangnirtung ca
# brusyliv ua
# bonfim br
# batagay ru
# mataura pf
# vaini to
# morristown us
# presidencia roque saenz pena ar
# butaritari ki
# doha kw
# kamaishi jp
# westport nz
# hambantota lk
# cabo san lucas mx
# malakal sd
# busselton au
# atar mr
# port macquarie au
# taolanaro mg
# klaksvik fo
# sarapulka ru
# vrangel ru
# busselton au
# ivdel ru
# klaksvik fo
# erenhot cn
# rikitea pf
# sao filipe cv
# khatanga ru
# punta arenas cl
# brae gb
# cherskiy ru
# taolanaro mg
# carnarvon au
# bambous virieux mu
# batemans bay au
# rikitea pf
# komsomolskiy ru
# qaanaaq gl
# tautira pf
# punta arenas cl
# mar del plata ar
# lebu cl
# mataura pf
# mar del plata ar
# busselton au
# taolanaro mg
# hobart au
# mkushi zm
# faanui pf
# bengkulu id
# arlit ne
# chapais ca
# abha sa
# mount isa au
# punta arenas cl
# geraldton au
# faanui pf
# pyshchug ru
# taolanaro mg
# hermanus za
# tautira pf
# ponta delgada pt
# cherskiy ru
# hermanus za
# valenca br
# cape town za
# hermanus za
# bluff nz
# bolshiye uki ru
# nguiu au
# puerto ayora ec
# hermanus za
# buala sb
# berlevag no
# jiblah ye
# cadillac us
# jamestown sh
# port macquarie au
# punta arenas cl
# mataura pf
# lakatoro vu
# smithers ca
# busselton au
# albany au
# ostrovnoy ru
# merta in
# belushya guba ru
# amderma ru
# tiksi ru
# homer us
# cape town za
# dubrajpur in
# guliston uz
# nanortalik gl
# avarua ck
# djibo bf
# polson us
# male mv
# illoqqortoormiut gl
# eyl so
# rikitea pf
# port alfred za
# port alfred za
# airai pw
# thompson ca
# saldanha za
# busselton au
# itaqui br
# namatanai pg
# albany au
# chapais ca
# hithadhoo mv
# carnarvon au
# kyaikkami mm
# namatanai pg
# eirunepe br
# ushuaia ar
# dikson ru
# taolanaro mg
# cherskiy ru
# henties bay na
# galiwinku au
# san ramon bo
# grand river south east mu
# belushya guba ru
# viligili mv
# kompaniyivka ua
# vaitupu wf
# rikitea pf
# vaini to
# thompson ca
# cidreira br
# ushuaia ar
# vaini to
# puerto ayora ec
# new norfolk au
# puerto escondido mx
# te anau nz
# rikitea pf
# nizhneyansk ru
# mataura pf
# nguiu au
# busselton au
# rikitea pf
# saldanha za
# cam ranh vn
# barrow us
# rikitea pf
# taolanaro mg
# pisco pe
# nuuk gl
# vaini to
# avarua ck
# port alfred za
# hobart au
# moranbah au
# fairbanks us
# saskylakh ru
# semnan ir
# kapaa us
# urumqi cn
# marcona pe
# san cristobal ec
# albany au
# rikitea pf
# tsihombe mg
# sao filipe cv
# hobart au
# muros es
# kununurra au
# mahebourg mu
# hobart au
# taolanaro mg
# payo ph
# kodiak us
# putina pe
# georgetown sh
# anloga gh
# cape town za
# lahij ye
# rikitea pf
# hithadhoo mv
# rikitea pf
# independence us
# arraial do cabo br
# faya td
# mounana ga
# rikitea pf
# tasiilaq gl
# sunrise us
# rikitea pf
# butaritari ki
# tasiilaq gl
# faya td
# ahipara nz
# taolanaro mg
# airai pw
# luau ao
# hamilton bm
# barrow us
# tsihombe mg
# brae gb
# chodavaram in
# moose factory ca
# kargil in
# westport nz
# vestmanna fo
# waitati nz
# ushuaia ar
# atuona pf
# tilichiki ru
# albany au
# sao filipe cv
# mandalgovi mn
# albany au
# saint george bm
# tundla in
# hermanus za
# tessalit ml
# bluff nz
# lahar in
# nanortalik gl
# kimbe pg
# erzin ru
# kuchinarai th
# sisimiut gl
# atuona pf
# hovd mn
# hobart au
# east london za
# yulara au
# mys shmidta ru
# bambous virieux mu
# berlevag no
# provideniya ru
# cidreira br
# vaini to
# harlingen nl
# yellowknife ca
# barentsburg sj
# port alfred za
# grahamstown za
# yellowknife ca
# port alfred za
# vaini to
# hobart au
# jambi id
# damoh in
# east london za
# araouane ml
# cherskiy ru
# bredasdorp za
# saint george bm
# harper lr
# ushuaia ar
# belushya guba ru
# east london za
# qaanaaq gl
# samusu ws
# glinishchevo ru
# obo cf
# linxia cn
# hilo us
# hermanus za
# barrow us
# tessalit ml
# jamestown sh
# ushuaia ar
# barentsburg sj
# hokitika nz
# rikitea pf
# mataura pf
# souillac mu
# alihe cn
# banda aceh id
# bulgan mn
# oksfjord no
# vaini to
# cayenne gf
# busselton au
# east london za
# punta arenas cl
# sentyabrskiy ru
# cape town za
# bluff nz
# arraial do cabo br
# aklavik ca
# busselton au
# taolanaro mg
# taolanaro mg
# cape town za
# albany au
# bluff nz
# bredasdorp za
# new norfolk au
# bajo baudo co
# port alfred za
# butaritari ki
# hambantota lk
# rikitea pf
# port elizabeth za
# kushima jp
# thompson ca
# albany au
# pevek ru
# jiazi cn
# carnarvon au
# albany au
# rikitea pf
# qaanaaq gl
# wattegama lk
# tandil ar
# nanortalik gl
# shingu jp
# jamestown sh
# dikson ru
# hasaki jp
# ahipara nz
# kapaa us
# lasa cn
# elko us
# bronnoysund no
# mataura pf
# grindavik is
# lebu cl
# rikitea pf
# albany au
# tiksi ru
# saint anthony ca
# barrow us
# gigant ru
# mataura pf
# yenangyaung mm
# georgetown sh
# ribeira grande pt
# bluff nz
# punta arenas cl
# tongchuan cn
# camacha pt
# qaanaaq gl
# cape town za
# tasiilaq gl
# oranjemund na
# rosetta eg
# dingle ie
# mar del plata ar
# kerman ir
# vestmannaeyjar is
# lata sb
# ambulu id
# amderma ru
# butaritari ki
# hilo us
# alofi nu
# vila velha br
# busselton au
# uige ao
# kodiak us
# lufilufi ws
# abu jubayhah sd
# east london za
# tuktoyaktuk ca
# provideniya ru
# barrow us
# port alfred za
# chuy uy
# chissamba ao
# camacha pt
# las vegas us
# salalah om
# east london za
# severo-kurilsk ru
# tome-acu br
# awbari ly
# albany au
# opuwo na
# meulaboh id
# puerto ayora ec
# neiafu to
# luderitz na
# hithadhoo mv
# ilulissat gl
# kruisfontein za
# ushuaia ar
# kostomuksha ru
# danielskuil za
# beringovskiy ru
# cape town za
# high rock bs
# anadyr ru
# bandar-e lengeh ir
# baykit ru
# aviles es
# acapulco mx
# norman wells ca
# asayita et
# hilo us
# port hedland au
# bengkulu id
# san pedro buenavista mx
# ribeira grande pt
# samusu ws
# fairlie nz
# pacific grove us
# bluff nz
# karoi zw
# norman wells ca
# kazalinsk kz
# amapa br
# qaanaaq gl
# sechelt ca
# baoning cn
# beringovskiy ru
# bluff nz
# rikitea pf
# jamestown sh
# vicksburg us
# hithadhoo mv
# barrow us
# mataura pf
# mys shmidta ru
# hobart au
# yellowknife ca
# barrow us
# kerki tm
# nenjiang cn
# khasan ru
# omboue ga
# kreminna ua
# illoqqortoormiut gl
# nikolskoye ru
# saint george bm
# punta arenas cl
# mataura pf
# port alfred za
# busselton au
# jamestown sh
# oriximina br
# andros town bs
# norman wells ca
# bluff nz
# cine tr
# dikson ru
# maceio br
# boende cd
# port lincoln au
# cape town za
# hermanus za
# illoqqortoormiut gl
# puerto ayora ec
# arraial do cabo br
# fortuna us
# sao joao da barra br
# vaini to
# esperance au
# dibulla co
# bontang id
# palabuhanratu id
# nagar karnul in
# hilo us
# mahadday weyne so
# yellowknife ca
# ishigaki jp
# barrow us
# montepuez mz
# sao filipe cv
# iqaluit ca
# daru pg
# port alfred za
# mahebourg mu
# avarua ck
# lebu cl
# darhan mn
# omboue ga
# mahajanga mg
# hilo us
# vaini to
# saint-junien fr
# araouane ml
# adrar dz
# fare pf
# bo phloi th
# chokurdakh ru
# svetlogorsk ru
# butaritari ki
# vila franca do campo pt
# miramar mx
# bredasdorp za
# kovrov ru
# sentyabrskiy ru
# hermanus za
# sa kaeo th
# guerrero negro mx
# hobart au
# asau tv
# marcona pe
# rikitea pf
# slave lake ca
# road town vg
# solnechnyy ru
# mys shmidta ru
# butaritari ki
# kapaa us
# khatanga ru
# ushuaia ar
# puerto ayora ec
# lagoa pt
# san cristobal do
# carnarvon au
# alofi nu
# honiara sb
# hilo us
# saskylakh ru
# saint-philippe re
# cherskiy ru
# alashtar ir
# puerto ayora ec
# thompson ca
# saint-georges gf
# hermanus za
# provideniya ru
# viedma ar
# port elizabeth za
# mizdah ly
# laguna br
# esperance au
# marsh harbour bs
# rikitea pf
# kapaa us
# tuktoyaktuk ca
# mataura pf
# wollongong au
# punta arenas cl
# cape town za
# mullaitivu lk
# fortuna us
# cape town za
# bolungarvik is
# punta arenas cl
# mataura pf
# albany au
# sentyabrskiy ru
# chambas cu
# saskylakh ru
# grand river south east mu
# busselton au
# tuktoyaktuk ca
# mecca sa
# santa maria cv
# alofi nu
# hobart au
# ilulissat gl
# busselton au
# bredasdorp za
# provideniya ru
# marcona pe
# airai pw
# siguiri gn
# hirara jp
# torbay ca
# siilinjarvi fi
# qaanaaq gl
# illoqqortoormiut gl
# quelimane mz
# barrow us
# ushuaia ar
# castro cl
# tateyama jp
# punta arenas cl
# ahipara nz
# tostamaa ee
# illoqqortoormiut gl
# dakar sn
# taolanaro mg
# saint george bm
# biltine td
# cabo san lucas mx
# hermanus za
# tuatapere nz
# hilo us
# kaitangata nz
# qui nhon vn
# hamilton bm
# busselton au
# bluff nz
# yellowknife ca
# albany au
# makakilo city us
# ternate id
# bani walid ly
# thompson ca
# port elizabeth za
# hermanus za
# atuona pf
# lolua tv
# nikolskoye ru
# cabo san lucas mx
# kuytun cn
# muros es
# constitucion mx
# shitkino ru
# sitka us
# puerto ayora ec
# olinda br
# yangambi cd
# butaritari ki
# saldanha za
# ribeira grande pt
# hithadhoo mv
# marcona pe
# rikitea pf
# tasiilaq gl
# jatai br
# hilo us
# coihaique cl
# port elizabeth za
# cacequi br
# ziro in
# yellowknife ca
# chemodanovka ru
# coahuayana mx
# taolanaro mg
# jamestown sh
# auburn us
# ushuaia ar
# isangel vu
# albany au
# taolanaro mg
# castro cl
# tuktoyaktuk ca
# yellowknife ca
# rikitea pf
# atuona pf
# qaanaaq gl
# hami cn
# rikitea pf
# santa rosa bo
# kavaratti in
# ilulissat gl
# fairbanks us
# vaini to
# biograd na moru hr
# oistins bb
# inirida co
# kiruna se
# cape town za
# rognan no
# geraldton au
# sungaipenuh id
# saint anthony ca
# provideniya ru
# tongliao cn
# faanui pf
# belushya guba ru
# illoqqortoormiut gl
# kaitangata nz
# henties bay na
# bedesa et
# mataura pf
# mar del plata ar
# vardo no
# cape town za
# karratha au
# jamestown sh
# qaqortoq gl
# georgetown sh
# requena pe
# avarua ck
# hilo us
# rikitea pf
# mount isa au
# hermanus za
# rikitea pf
# misratah ly
# khatanga ru
# sentyabrskiy ru
# rikitea pf
# nantucket us
# bluff nz
# rikitea pf
# bayshore gardens us
# port alfred za
# flin flon ca
# kapaa us
# bambous virieux mu
# davila ph
# shakhtinsk kz
# inhambane mz
# vanimo pg
# butaritari ki
# ubeda es
# kavieng pg
# kavaratti in
# vwawa tz
# phan thiet vn
# ziro in
# svetlogorsk ru
# port hedland au
# iskateley ru
# georgetown sh
# kodiak us
# bandarbeyla so
# ostersund se
# lebu cl
# busselton au
# mataura pf
# albany au
# grand river south east mu
# vestmanna fo
# cape town za
# albany au
# hermanus za
# hamilton bm
# tuktoyaktuk ca
# tuatapere nz
# linhares br
# noumea nc
# hami cn
# kaka tm
# quelimane mz
# shimoda jp
# ushuaia ar
# santa isabel do rio negro br
# meiktila mm
# mantua cu
# ushuaia ar
# castro cl
# busselton au
# kidal ml
# bluff nz
# cherskiy ru
# rikitea pf
# lake havasu city us
# pemangkat id
# kapaa us
# new norfolk au
# camana pe
# tiksi ru
# cape town za
# patamea ws
# castro cl
# vaini to
# pacific grove us
# pevek ru
# mataura pf
# hilo us
# hermanus za
# emba kz
# severo-kurilsk ru
# ilulissat gl
# ushuaia ar
# alice springs au
# sikonge tz
# cape town za
# cauquenes cl
# provideniya ru
# new norfolk au
# barrow us
# longyearbyen sj
# punta arenas cl
# taolanaro mg
# bluff nz
# albany au
# lebu cl
# san cristobal ec
# talnakh ru
# east london za
# bredasdorp za
# mumford gh
# gariaband in
# quesnel ca
# maceio br
# severo-kurilsk ru
# kedougou sn
# maputo mz
# tsihombe mg
# oum hadjer td
# nikolskoye ru
# greenfield us
# arraial do cabo br
# beaverlodge ca
# belushya guba ru
# cape town za
# srednekolymsk ru
# tiznit ma
# taolanaro mg
# mataura pf
# bredasdorp za
# lufilufi ws
# taolanaro mg
# kaitangata nz
# cape town za
# kapaa us
# hermanus za
# taolanaro mg
# port alfred za
# kapaa us
# sacel ro
# ushuaia ar
# tura ru
# ushuaia ar
# atuona pf
# severo-kurilsk ru
# viligili mv
# husavik is
# avarua ck
# provideniya ru
# upernavik gl
# atuona pf
# north bend us
# tuktoyaktuk ca
# bababe mr
# tuatapere nz
# tongzi cn
# luderitz na
# beringovskiy ru
# saleaula ws
# coquimbo cl
# porto novo cv
# ushuaia ar
# mar del plata ar
# aktash ru
# bambous virieux mu
# deputatskiy ru
# mataura pf
# port alfred za
# bredasdorp za
# georgetown sh
# yachiyo jp
# tateyama jp
# jamestown sh
# saleaula ws
# lebu cl
# illoqqortoormiut gl
# victoria sc
# taolanaro mg
# mogadishu so
# mataura pf
# ushuaia ar
# butaritari ki
# bambous virieux mu
# dolinsk ru
# cidreira br
# ushuaia ar
# clyde river ca
# aconibe gq
# barrow us
# new norfolk au
# vaini to
# san buenaventura mx
# aksu kz
# rio gallegos ar
# taclobo ph
# san luis mx
# santa fe cu
# east london za
# the valley ai
# kruisfontein za
# longyearbyen sj
# busselton au
# mergui mm
# svetlogorsk ru
# saryshagan kz
# cherskiy ru
# komsomolskiy ru
# gambela et
# barra patuca hn
# tessalit ml
# kapaa us
# new norfolk au
# ulaanbaatar mn
# chokurdakh ru
# albany au
# borzya ru
# maloshuyka ru
# illoqqortoormiut gl
# castro cl
# punta arenas cl
# hermanus za
# rikitea pf
# albany au
# williams lake ca
# lebu cl
# vaini to
# butaritari ki
# kruisfontein za
# puerto ayora ec
# nizhniy baskunchak ru
# punta arenas cl
# belushya guba ru
# taolanaro mg
# ushuaia ar
# kautokeino no
# ponta do sol cv
# doha qa
# barrow us
# te anau nz
# hermanus za
# grand river south east mu
# klaksvik fo
# punta arenas cl
# kruisfontein za
# mys shmidta ru
# kabelvag no
# atuona pf
# tuktoyaktuk ca
# miraflores co
# albany au
# point fortin tt
# bluff nz
# bathsheba bb
# narsaq gl
# aksarka ru
# aquiraz br
# taolanaro mg
# mhango tz
# tucuma br
# pakokku mm
# lorengau pg
# taylorville us
# fort saint john ca
# talavera de la reina es
# cape town za
# broken hill au
# taolanaro mg
# chokurdakh ru
# pavlodar kz
# yellowknife ca
# jamestown sh
# iberia pe
# port alfred za
# tuktoyaktuk ca
# bom conselho br
# rikitea pf
# xining cn
# dikson ru
# qaanaaq gl
# mataura pf
# hilo us
# hobart au
# bluff nz
# hermanus za
# nizhniy ingash ru
# bambous virieux mu
# rikitea pf
# tiksi ru
# cockburn harbour tc
# butaritari ki
# east london za
# arraial do cabo br
# bluff nz
# hermanus za
# khatanga ru
# debre zeyit et
# ancud cl
# shipitsyno ru
# pathein mm
# kapaa us
# butaritari ki
# bardiyah ly
# bubaque gw
# wewak pg
# faanui pf
# san patricio mx
# east london za
# honningsvag no
# hilo us
# ushuaia ar
# castro cl
# cherskiy ru
# san quintin mx
# hilo us
# huilong cn
# penzance gb
# parintins br
# kjollefjord no
# varhaug no
# mega et
# east london za
# kapaa us
# taolanaro mg
# souillac mu
# bethel us
# mataura pf
# jieshi cn
# fare pf
# ust-kuyga ru
# cidreira br
# sentyabrskiy ru
# moranbah au
# grand-santi gf
# tonala mx
# east london za
# norfolk us
# avarua ck
# kapaa us
# taolanaro mg
# point pleasant us
# jiblah ye
# sobolevo ru
# ponta do sol cv
# atuona pf
# carrollton us
# ponta delgada pt
# illoqqortoormiut gl
# ushuaia ar
# kahului us
# sakakah sa
# trinidad bo
# cape town za
# zhigansk ru
# rikitea pf
# saint-pie ca
# ushuaia ar
# mataura pf
# la rioja ar
# bluff nz
# sterlibashevo ru
# masallatah ly
# palabuhanratu id
# kaitangata nz
# severo-kurilsk ru
# illoqqortoormiut gl
# rikitea pf
# bluff nz
# padang id
# taolanaro mg
# taolanaro mg
# vaini to
# korla cn
# ushuaia ar
# maputo mz
# kapaa us
# chicama pe
# atuona pf
# busselton au
# corvallis us
# tuktoyaktuk ca
# rikitea pf
# mocambique mz
# sorland no
# atuona pf
# thompson ca
# port-gentil ga
# ushuaia ar
# saint-pierre pm
# trincomalee lk
# roald no
# shimoda jp
# chuy uy
# madera mx
# cockburn town bs
# vaitupu wf
# palabuhanratu id
# barentsburg sj
# berlevag no
# sicula ro
# athabasca ca
# coahuayana mx
# pacific grove us
# okha ru
# east london za
# waipawa nz
# tuktoyaktuk ca
# kungurtug ru
# bredasdorp za
# axim gh
# nikolskoye ru
# punta arenas cl
# avera pf
# mataura pf
# barrow us
# ilulissat gl
# kapaa us
# ushuaia ar
# lhokseumawe id
# punta arenas cl
# butaritari ki
# umzimvubu za
# taolanaro mg
# kavaratti in
# fortuna us
# somerset us
# coihaique cl
# hobyo so
# butaritari ki
# tuktoyaktuk ca
# hobart au
# georgetown sh
# zavodskoy ru
# busselton au
# illoqqortoormiut gl
# kalengwa zm
# san luis pe
# davila ph
# punta arenas cl
# mataura pf
# east london za
# taolanaro mg
# nuuk gl
# tuktoyaktuk ca
# solnechnyy ru
# port elizabeth za
# punta arenas cl
# dzhusaly kz
# saint-philippe re
# bathsheba bb
# vaini to
# kroya id
# punta arenas cl
# nanortalik gl
# cape town za
# denpasar id
# cape town za
# punta arenas cl
# taolanaro mg
# ushuaia ar
# busselton au
# hay river ca
# saleaula ws
# jamestown sh
# busselton au
# provideniya ru
# shelburne ca
# dikson ru
# rikitea pf
# tuktoyaktuk ca
# rikitea pf
# senmonorom kh
# punta arenas cl
# taolanaro mg
# barentsburg sj
# busselton au
# leningradskiy ru
# acarau br
# amderma ru
# marzuq ly
# samusu ws
# paradwip in
# rikitea pf
# nelson bay au
# yazykovo ru
# salinas ec
# rikitea pf
# brus laguna hn
# talaya ru
# gornopravdinsk ru
# santa lucia es
# tuktoyaktuk ca
# amderma ru
# barentsburg sj
# fortuna us

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 636

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=70619ace23cacf12ed2f26529fcc589c

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Toronto"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=70619ace23cacf12ed2f26529fcc589c&q=Toronto

# %%
import requests
requests.__version__
# Out:
# '2.25.1'

# %%
import requests
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key
city = "London"

# %%
query_url = url + "appid" + weather_api_key + "&q" + city

# %%
# Make a 'Get' request for the city weather.
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
city_weather.status_code
# Out:
# 200

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Toronto"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Toronto"
city_weather = requests.get(city_url)
city_weather
# Out:
# <Response [200]>

# %%
# Get the text of the 'Get' request.
city_weather.text
# Out:
# '{"coord":{"lon":-79.4163,"lat":43.7001},"weather":[{"id":802,"main":"Clouds","description":"scattered clouds","icon":"03d"}],"base":"stations","main":{"temp":19.37,"feels_like":19.43,"temp_min":17.42,"temp_max":21.72,"pressure":1019,"humidity":79},"visibility":10000,"wind":{"speed":1.34,"deg":59,"gust":4.02},"clouds":{"all":40},"dt":1633722021,"sys":{"type":1,"id":718,"country":"CA","sunrise":1633692213,"sunset":1633733184},"timezone":-14400,"id":6167865,"name":"Toronto","cod":200}'

# %%
# Get the JSON text of the 'Get' request.
city_weather.json()
# Out:
# {'coord': {'lon': -79.4163, 'lat': 43.7001},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 19.37,
#   'feels_like': 19.43,
#   'temp_min': 17.42,
#   'temp_max': 21.72,
#   'pressure': 1019,
#   'humidity': 79},
#  'visibility': 10000,
#  'wind': {'speed': 1.34, 'deg': 59, 'gust': 4.02},
#  'clouds': {'all': 40},
#  'dt': 1633722021,
#  'sys': {'type': 1,
#   'id': 718,
#   'country': 'CA',
#   'sunrise': 1633692213,
#   'sunset': 1633733184},
#  'timezone': -14400,
#  'id': 6167865,
#  'name': 'Toronto',
#  'cod': 200}

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Toronto"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City Weather found.

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Torontos"
city_weather = requests.get(city_url)
if city_weather.status_code == 200:
    print(f"City Weather found.")
else:
    print(f"City weather not found.")
# Out:
# City weather not found.

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=70619ace23cacf12ed2f26529fcc589c&q=Torontos

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Toronto"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -79.4163, 'lat': 43.7001},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04d'}],
#  'base': 'stations',
#  'main': {'temp': 19.68,
#   'feels_like': 19.71,
#   'temp_min': 17.53,
#   'temp_max': 21.75,
#   'pressure': 1018,
#   'humidity': 77},
#  'visibility': 10000,
#  'wind': {'speed': 0.89, 'deg': 37, 'gust': 2.24},
#  'clouds': {'all': 100},
#  'dt': 1633723645,
#  'sys': {'type': 2,
#   'id': 2010632,
#   'country': 'CA',
#   'sunrise': 1633692213,
#   'sunset': 1633733184},
#  'timezone': -14400,
#  'id': 6167865,
#  'name': 'Toronto',
#  'cod': 200}

# %%
# Get the JSON data.
toronto_data = city_weather.json()

# %%
toronto_data["sys"]
# Out:
# {'type': 2,
#  'id': 2010632,
#  'country': 'CA',
#  'sunrise': 1633692213,
#  'sunset': 1633733184}

# %%
toronto_data["sys"]["country"]
# Out:
# 'CA'

# %%
toronto_data["dt"]
# Out:
# 1633723645

# %%
toronto_data["coord"]["lat"]
# Out:
# 43.7001

# %%
toronto_data["main"]["temp_max"]
# Out:
# 21.75

# %%
lat = toronto_data["coord"]["lat"]
lng = toronto_data["coord"]["lon"]
max_temp = toronto_data["main"]["temp_max"]
humidity = toronto_data["main"]["humidity"]
clouds = toronto_data["clouds"]["all"]
wind = toronto_data["wind"]["speed"]
print(lat, lng, max_temp, humidity, clouds, wind)
# Out:
# 43.7001 -79.4163 21.75 77 100 0.89

# %%
# Import the datetime module from the datetime library.
from datetime import datetime
# Get the date from the JSON file.
date = toronto_data["dt"]
# Convert the UTC date to a date format with year, month, day, hours, minutes, and seconds.
datetime.utcfromtimestamp(date).strftime('%Y-%m-%d %H:%M:%S')
# Out:
# '2021-10-08 20:07:25'
